# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(pd.read_csv('/train.csv'))
df.head()

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0e566b70f572> in <module>()
# ----> 1 df.shape()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-629914d6d1c7> in <module>()
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined
